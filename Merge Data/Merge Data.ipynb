# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_csv('1400 chris92.csv')
df1.head(5)
# Out:
#                                        Title
# 0     {PS4} [SQTR] Sky Limits #2 (Squall-TR)  \
# 1   {PS4} [SQTR] Moto PanTour #2 (Squall-TR)
# 2          {PS4} {KV}M.R PokeBola (kevvon35)
# 3     {PS4} [SQTR] Skill Fast #1 (Squall-TR)
# 4  {PS4} [SQTR] Crazy Airport #2 (Squall-TR)
#
#                                                Image
# 0  https://prod.cloud.rockstargames.com/ugc/gta5m...  \
# 1  https://prod.cloud.rockstargames.com/ugc/gta5m...
# 2  https://prod.cloud.rockstargames.com/ugc/gta5m...
# 3  https://prod.cloud.rockstargames.com/ugc/gta5m...
# 4  https://prod.cloud.rockstargames.com/ugc/gta5m...
#
#                             ugccard__wrap__2dpy7_URL
# 0  https://socialclub.rockstargames.com/job/gtav/...  \
# 1  https://socialclub.rockstargames.com/job/gtav/...
# 2  https://socialclub.rockstargames.com/job/gtav/...
# 3  https://socialclub.rockstargames.com/job/gtav/...
# 4  https://socialclub.rockstargames.com/job/gtav/...
#
# ...

# %%
df2 = pd.read_csv('1500 parkour.csv')
df2.head(5)
# Out:
#                                             Title
# 0              {PS5} [$P] Peachkour (Sara-Peachy)  \
# 1                    【HD系列】53 [笑里藏刀之五] 炸 Distance
# 2                                         Parkour
# 3                       parkour à pied (Find way)
# 4  {PS4} [mic] XA21 STUNT-KOUR #2 (MICRO_HACK_YT)
#
#                                                Image
# 0  https://prod.cloud.rockstargames.com/ugc/gta5m...  \
# 1  https://prod.cloud.rockstargames.com/ugc/gta5m...
# 2  https://prod.cloud.rockstargames.com/ugc/gta5m...
# 3  https://prod.cloud.rockstargames.com/ugc/gta5m...
# 4  https://prod.cloud.rockstargames.com/ugc/gta5m...
#
#                             ugccard__wrap__2dpy7_URL
# 0  https://socialclub.rockstargames.com/job/gtav/...  \
# 1  https://socialclub.rockstargames.com/job/gtav/...
# 2  https://socialclub.rockstargames.com/job/gtav/...
# 3  https://socialclub.rockstargames.com/job/gtav/...
# 4  https://socialclub.rockstargames.com/job/gtav/...
#
# ...

# %%
df3 = pd.read_csv('3000 xygu.csv')
df3.head(5)
# Out:
#                                                Title
# 0  {PS4} Porkmodz carkour 63{Roma} (Romanaccio_Modz)  \
# 1          {PS4} SITH]Face to F BobEsponja (sith_JC)
# 2         {PS4} - - - [JP90] Face to Face (josepo90)
# 3        {PS4} AirGermany Parkour #246 (DaveStylemh)
# 4          {PS4} [SITH]Parkour FALL GUYS!! (sith_JC)
#
#                                                Image
# 0  https://prod.cloud.rockstargames.com/ugc/gta5m...  \
# 1  https://prod.cloud.rockstargames.com/ugc/gta5m...
# 2  https://prod.cloud.rockstargames.com/ugc/gta5m...
# 3  https://prod.cloud.rockstargames.com/ugc/gta5m...
# 4  https://prod.cloud.rockstargames.com/ugc/gta5m...
#
#                             ugccard__wrap__2dpy7_URL
# 0  https://socialclub.rockstargames.com/job/gtav/...  \
# 1  https://socialclub.rockstargames.com/job/gtav/...
# 2  https://socialclub.rockstargames.com/job/gtav/...
# 3  https://socialclub.rockstargames.com/job/gtav/...
# ...

# %%
df4 = pd.read_csv('5000 parkour.csv')
df4.head(5)
# Out:
#                                             Title
# 0  {PS4} [PM] Parkour Ruiner 2000 (patoudemoorea)  \
# 1              {PS5} [$P] Peachkour (Sara-Peachy)
# 2                    【HD系列】53 [笑里藏刀之五] 炸 Distance
# 3                                         Parkour
# 4                       parkour à pied (Find way)
#
#                                                Image
# 0  https://prod.cloud.rockstargames.com/ugc/gta5m...  \
# 1  https://prod.cloud.rockstargames.com/ugc/gta5m...
# 2  https://prod.cloud.rockstargames.com/ugc/gta5m...
# 3  https://prod.cloud.rockstargames.com/ugc/gta5m...
# 4  https://prod.cloud.rockstargames.com/ugc/gta5m...
#
#                             ugccard__wrap__2dpy7_URL
# 0  https://socialclub.rockstargames.com/job/gtav/...  \
# 1  https://socialclub.rockstargames.com/job/gtav/...
# 2  https://socialclub.rockstargames.com/job/gtav/...
# 3  https://socialclub.rockstargames.com/job/gtav/...
# 4  https://socialclub.rockstargames.com/job/gtav/...
#
# ...

# %%
df5 = pd.read_csv('600 air germany.csv')
df5.head(5)
# Out:
#                                                Title
# 0        {PS5} AirGermany Parkour #584 (DaveStylemh)  \
# 1        {PS4} AirGermany Parkour #583 (DaveStylemh)
# 2        {PS4} AirGermany Parkour #582 (DaveStylemh)
# 3  {PS4} AirGermany Parkour #506 (DaveStylemh) HA...
# 4                                   Battle of Warsaw
#
#                                                Image
# 0  https://prod.cloud.rockstargames.com/ugc/gta5m...  \
# 1  https://prod.cloud.rockstargames.com/ugc/gta5m...
# 2  https://prod.cloud.rockstargames.com/ugc/gta5m...
# 3  https://prod.cloud.rockstargames.com/ugc/gta5m...
# 4  https://prod.cloud.rockstargames.com/ugc/gta5m...
#
#                             ugccard__wrap__2dpy7_URL
# 0  https://socialclub.rockstargames.com/job/gtav/...  \
# 1  https://socialclub.rockstargames.com/job/gtav/...
# 2  https://socialclub.rockstargames.com/job/gtav/...
# 3  https://socialclub.rockstargames.com/job/gtav/...
# ...

# %%
df6 = pd.read_csv('70 bigodao.csv')
df6.head(5)
# Out:
#                                             Title
# 0      {PS4} {SOLD} CARKOUD14S 9 ! (JohnnyKammos)  \
# 1   {PS4} {SOLD}LIPONES BIGODAO 4! (JohnnyKammos)
# 2  {PS4} {SOLD} LIPONES BIGODAO 5! (JohnnyKammos)
# 3  {PS4} {SOLD} LIPONES BIGODAO 7! (JohnnyKammos)
# 4  {PS4} {SOLD} LIPONES BIGODAO 6! (JohnnyKammos)
#
#                                                Image
# 0  https://prod.cloud.rockstargames.com/ugc/gta5m...  \
# 1  https://prod.cloud.rockstargames.com/ugc/gta5m...
# 2  https://prod.cloud.rockstargames.com/ugc/gta5m...
# 3  https://prod.cloud.rockstargames.com/ugc/gta5m...
# 4  https://prod.cloud.rockstargames.com/ugc/gta5m...
#
#                             ugccard__wrap__2dpy7_URL
# 0  https://socialclub.rockstargames.com/job/gtav/...  \
# 1  https://socialclub.rockstargames.com/job/gtav/...
# 2  https://socialclub.rockstargames.com/job/gtav/...
# 3  https://socialclub.rockstargames.com/job/gtav/...
# 4  https://socialclub.rockstargames.com/job/gtav/...
#
# ...

# %%
df7 = pd.read_csv('80 lipao megarampe.csv')
df7.head(5)
# Out:
#                                                Title
# 0  {PS4} Lipao Megarampe 103{Roma} (Romanaccio_Kill)  \
# 1  {PS4} Lipao MegaRampe102 {Roma} (Romanaccio_Kill)
# 2  {PS4} Lipao MegaRampe 101{Roma} (Romanaccio_Kill)
# 3  {PS4} Lipao MegaRampe 99 {Roma} (Romanaccio_Kill)
# 4  {PS4} Lipao megarampe 100{Roma} (Romanaccio_Kill)
#
#                                                Image
# 0  https://prod.cloud.rockstargames.com/ugc/gta5m...  \
# 1  https://prod.cloud.rockstargames.com/ugc/gta5m...
# 2  https://prod.cloud.rockstargames.com/ugc/gta5m...
# 3  https://prod.cloud.rockstargames.com/ugc/gta5m...
# 4  https://prod.cloud.rockstargames.com/ugc/gta5m...
#
#                             ugccard__wrap__2dpy7_URL
# 0  https://socialclub.rockstargames.com/job/gtav/...  \
# 1  https://socialclub.rockstargames.com/job/gtav/...
# 2  https://socialclub.rockstargames.com/job/gtav/...
# 3  https://socialclub.rockstargames.com/job/gtav/...
# ...

# %%
df8 = pd.read_csv('90 sniffer.csv')
df8.head(5)
# Out:
#                                Title
# 0  [GTM156] Sniffer821 Parkour Final  \
# 1     [GTM154] Ramp Buggy Parkour #1
# 2    [GTM152] Freecrawler Parkour #8
# 3     [GTM151] Issi Rally Parkour #1
# 4      [GTM150] Crazy Mega Rampa #21
#
#                                                Image
# 0  https://prod.cloud.rockstargames.com/ugc/gta5m...  \
# 1  https://prod.cloud.rockstargames.com/ugc/gta5m...
# 2  https://prod.cloud.rockstargames.com/ugc/gta5m...
# 3  https://prod.cloud.rockstargames.com/ugc/gta5m...
# 4  https://prod.cloud.rockstargames.com/ugc/gta5m...
#
#                             ugccard__wrap__2dpy7_URL
# 0  https://socialclub.rockstargames.com/job/gtav/...  \
# 1  https://socialclub.rockstargames.com/job/gtav/...
# 2  https://socialclub.rockstargames.com/job/gtav/...
# 3  https://socialclub.rockstargames.com/job/gtav/...
# 4  https://socialclub.rockstargames.com/job/gtav/...
#
#                                             User_URL        User
# ...

# %%
df9 = pd.read_csv('900 freecrawler.csv')
df9.head(5)
# Out:
#                                               Title
# 0                                {XEN} SkillTest #2  \
# 1         {PS5} #BLG FREECRAWLER PARKOUR (BobLaGPU)
# 2  {PS4} [ML8]- Freecrawler_kour (Mapache_loco_8cl)
# 3         {PS4} [O-Z] CANIS FREECRAWLER (O-Z_31100)
# 4                              The Art of Parkour 7
#
#                                                Image
# 0  https://prod.cloud.rockstargames.com/ugc/gta5m...  \
# 1  https://prod.cloud.rockstargames.com/ugc/gta5m...
# 2  https://prod.cloud.rockstargames.com/ugc/gta5m...
# 3  https://prod.cloud.rockstargames.com/ugc/gta5m...
# 4  https://prod.cloud.rockstargames.com/ugc/gta5m...
#
#                             ugccard__wrap__2dpy7_URL
# 0  https://socialclub.rockstargames.com/job/gtav/...  \
# 1  https://socialclub.rockstargames.com/job/gtav/...
# 2  https://socialclub.rockstargames.com/job/gtav/...
# 3  https://socialclub.rockstargames.com/job/gtav/...
# 4  https://socialclub.rockstargames.com/job/gtav/...
#
# ...

# %%
df10 = pd.read_csv('hard parkour 1000.csv')
df10.head(5)
# Out:
#                                        Title
# 0                           Hard Parkour T20  \
# 1  {PS5} #BLG FREECRAWLER PARKOUR (BobLaGPU)
# 2            {XB1} FJ's BMX Parkour (LuniFJ)
# 3                     DRAGON HARD PARKOUR V8
# 4                  £''{Tropical} Parkour ''£
#
#                                                Image
# 0  https://prod.cloud.rockstargames.com/ugc/gta5m...  \
# 1  https://prod.cloud.rockstargames.com/ugc/gta5m...
# 2  https://prod.cloud.rockstargames.com/ugc/gta5m...
# 3  https://prod.cloud.rockstargames.com/ugc/gta5m...
# 4  https://prod.cloud.rockstargames.com/ugc/gta5m...
#
#                             ugccard__wrap__2dpy7_URL
# 0  https://socialclub.rockstargames.com/job/gtav/...  \
# 1  https://socialclub.rockstargames.com/job/gtav/...
# 2  https://socialclub.rockstargames.com/job/gtav/...
# 3  https://socialclub.rockstargames.com/job/gtav/...
# 4  https://socialclub.rockstargames.com/job/gtav/...
#
# ...

# %%
df11 = pd.read_csv('not good.csv')
df11.head(5)
# Out:
#                                 Title
# 0                 parkour modz (cayo)  \
# 1            PARKOUR MODDS°]*****[;;;
# 2      [GTM154] Ramp Buggy Parkour #1
# 3  {PS4} {E_} Eudora KOUR (ersino_YT)
# 4     faggio mod parkour - THE ARVIND
#
#                                                Image
# 0  https://prod.cloud.rockstargames.com/ugc/gta5m...  \
# 1  https://prod.cloud.rockstargames.com/ugc/gta5m...
# 2  https://prod.cloud.rockstargames.com/ugc/gta5m...
# 3  https://prod.cloud.rockstargames.com/ugc/gta5m...
# 4  https://prod.cloud.rockstargames.com/ugc/gta5m...
#
#                             ugccard__wrap__2dpy7_URL
# 0  https://socialclub.rockstargames.com/job/gtav/...  \
# 1  https://socialclub.rockstargames.com/job/gtav/...
# 2  https://socialclub.rockstargames.com/job/gtav/...
# 3  https://socialclub.rockstargames.com/job/gtav/...
# 4  https://socialclub.rockstargames.com/job/gtav/...
#
#                                             User_URL            User
# ...

# %%
df12 = pd.read_csv('yello 30.csv')
df12.head(5)
# Out:
#                                          Title
# 0      {PS4} -Wild Ride Downtown-  (Yellowdex)  \
# 1  {PS4} -Aquarius Castle- Parkour (Yellowdex)
# 2       {PS4} -Goosed Tricky Path- (Yellowdex)
# 3   {PS4} -Lake of Fire 4--Parkour (Yellowdex)
# 4      {PS4} -Goosed Rallycross 2- (Yellowdex)
#
#                                                Image
# 0  https://prod.cloud.rockstargames.com/ugc/gta5m...  \
# 1  https://prod.cloud.rockstargames.com/ugc/gta5m...
# 2  https://prod.cloud.rockstargames.com/ugc/gta5m...
# 3  https://prod.cloud.rockstargames.com/ugc/gta5m...
# 4  https://prod.cloud.rockstargames.com/ugc/gta5m...
#
#                             ugccard__wrap__2dpy7_URL
# 0  https://socialclub.rockstargames.com/job/gtav/...  \
# 1  https://socialclub.rockstargames.com/job/gtav/...
# 2  https://socialclub.rockstargames.com/job/gtav/...
# 3  https://socialclub.rockstargames.com/job/gtav/...
# 4  https://socialclub.rockstargames.com/job/gtav/...
#
# ...

# %%
FinalDF = pd.concat([df1,df2,df3,df4,df5,df6,df7,df8,df9,df10,df11,df12]).drop_duplicates()

# %%
concatRes
# Out:
#                                           Title
# 0        {PS4} [SQTR] Sky Limits #2 (Squall-TR)  \
# 1      {PS4} [SQTR] Moto PanTour #2 (Squall-TR)
# 2             {PS4} {KV}M.R PokeBola (kevvon35)
# 3        {PS4} [SQTR] Skill Fast #1 (Squall-TR)
# 4     {PS4} [SQTR] Crazy Airport #2 (Squall-TR)
# ..                                          ...
# 25      {PS4} $$$ [[Cliffhanger 2]] (Yellowdex)
# 26         {PS4} Parkour the City 2 (Yellowdex)
# 30      {PS4} -Prison Break Detour- (Yellowdex)
# 31  {PS4} $$$[[Boxed in! Get out!]] (Yellowdex)
# 32       {PS4} [[[[[Waterworld]]]]] (Yellowdex)
#
#                                                 Image
# 0   https://prod.cloud.rockstargames.com/ugc/gta5m...  \
# 1   https://prod.cloud.rockstargames.com/ugc/gta5m...
# 2   https://prod.cloud.rockstargames.com/ugc/gta5m...
# 3   https://prod.cloud.rockstargames.com/ugc/gta5m...
# 4   https://prod.cloud.rockstargames.com/ugc/gta5m...
# ..                                                ...
# ...

# %%
FinalDF.to_csv('finaldf.csv')

# %%
FinalDF.duplicated().sum()
# Out:
# 0
